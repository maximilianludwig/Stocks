# %%
import import_ipynb
import Fresh_Bot 
from Fresh_Bot import *
from datetime import *
# Out:
# importing Jupyter notebook from Fresh_Bot.ipynb
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\ta\trend.py:608: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\ta\trend.py:612: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])
# buy

# %%
today = date.today()
end_day = today.strftime("%Y-%m-%d")
start_day = today - timedelta(days=200)
start_day = start_day.strftime("%Y-%m-%d")

# %%
dax = Fresh_Bot.decide("^GDAXI", start_day, end_day)

# %%
trade_for_today(dax)
# Out:
# buy

# %%
amazon = Fresh_Bot.decide("AMZN", start_day, end_day)
trade_for_today(amazon)
# Out:
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\ta\trend.py:608: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\ta\trend.py:612: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])
# buy

# %%
appel = Fresh_Bot.decide("AAPL", start_day, end_day)
trade_for_today(appel)
# Out:
# buy

# %%
msft = Fresh_Bot.decide("MSFT", start_day, end_day)
trade_for_today(msft)
plot_decision(msft)
# Out:
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\ta\trend.py:608: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# C:\Users\A675866\AppData\Local\Continuum\anaconda3\lib\site-packages\ta\trend.py:612: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])
# Do nothing

# %%
#Next, flask server that can check few given stocks whether a buy, sell or nothing makes sense. Trigger is manual

# %%
from flask import Flask
from werkzeug.wrappers import Request, Response
app = Flask(__name__)

# %%
@app.route('/')
def show_stocks():
    return 'Hello, World!'

# %%
if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9000, app)
# Out:
#  * Running on http://localhost:9000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/May/2020 16:29:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2020 16:29:21] "GET /favicon.ico HTTP/1.1" 404 -
